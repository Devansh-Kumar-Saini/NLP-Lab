# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download required NLTK data
nltk.download('stopwords')
nltk.download('punkt')

# %%
def remove_stopwords():
    text = """
    Natural Language Processing is a subfield of artificial intelligence 
    that focuses on the interaction between computers and humans using natural language.
    """
    
    # Tokenize the text
    words = word_tokenize(text)
    print("Original words:", words)
    
    # Get English stop words
    stop_words = set(stopwords.words('english'))
    print(f"\nStop words in English: {list(stop_words)[:10]}...")  # Show first 10
    
    # Remove stop words
    filtered_words = [word for word in words if word.lower() not in stop_words and word.isalpha()]
    
    print("\nAfter removing stop words:")
    print(filtered_words)
    
    return filtered_words

# %%
if __name__ == "__main__":
    remove_stopwords()
# Out:
# Original words: ['Natural', 'Language', 'Processing', 'is', 'a', 'subfield', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'using', 'natural', 'language', '.']
#
# Stop words in English: ['will', 'what', 'just', 'once', "should've", 'again', 'm', 'shan', "he's", 'didn']...
#
# After removing stop words:
# ['Natural', 'Language', 'Processing', 'subfield', 'artificial', 'intelligence', 'focuses', 'interaction', 'computers', 'humans', 'using', 'natural', 'language']
