# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag, ne_chunk

# %%
# Download required NLTK data
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\Devansh
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to C:\Users\Devansh
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Devansh Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to C:\Users\Devansh
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def perform_ner():
    text = """
    Apple Inc. is headquartered in Cupertino, California. 
    Tim Cook is the CEO of Apple. 
    Microsoft was founded by Bill Gates in Redmond, Washington.
    Elon Musk leads Tesla and SpaceX from Texas.
    """
    
    # Tokenize and POS tag
    words = word_tokenize(text)
    pos_tags = pos_tag(words)
    
    print("POS Tags:", pos_tags)
    
    # Perform Named Entity Recognition
    ner_tree = ne_chunk(pos_tags)
    
    print("\nNER Result:")
    print(ner_tree)
    
    # Extract named entities
    print("\nNamed Entities:")
    entities = []
    for chunk in ner_tree:
        if hasattr(chunk, 'label'):
            entity_text = ' '.join(c[0] for c in chunk)
            entity_type = chunk.label()
            entities.append((entity_text, entity_type))
            print(f"Entity: {entity_text:<25} Type: {entity_type}")
    
    return entities

# %%
if __name__ == "__main__":
    perform_ner()
# Out:
# POS Tags: [('Apple', 'NNP'), ('Inc.', 'NNP'), ('is', 'VBZ'), ('headquartered', 'VBN'), ('in', 'IN'), ('Cupertino', 'NNP'), (',', ','), ('California', 'NNP'), ('.', '.'), ('Tim', 'NNP'), ('Cook', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('CEO', 'NNP'), ('of', 'IN'), ('Apple', 'NNP'), ('.', '.'), ('Microsoft', 'NNP'), ('was', 'VBD'), ('founded', 'VBN'), ('by', 'IN'), ('Bill', 'NNP'), ('Gates', 'NNP'), ('in', 'IN'), ('Redmond', 'NNP'), (',', ','), ('Washington', 'NNP'), ('.', '.'), ('Elon', 'NNP'), ('Musk', 'NNP'), ('leads', 'VBZ'), ('Tesla', 'NNP'), ('and', 'CC'), ('SpaceX', 'NNP'), ('from', 'IN'), ('Texas', 'NNP'), ('.', '.')]
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 if __name__ == "__main__":
# ----> 2     perform_ner()
#
# Cell In[5], line 16, in perform_ner()
#      13 print("POS Tags:", pos_tags)
#      15 # Perform Named Entity Recognition
# ---> 16 ner_tree = ne_chunk(pos_tags)
#      18 print("\nNER Result:")
#      19 print(ner_tree)
#
# File d:\Devansh\Amity\Sem 7\NLP\Lab\.venv\Lib\site-packages\nltk\chunk\__init__.py:192, in ne_chunk(tagged_tokens, binary)
#     190     chunker = ne_chunker(fmt="binary")
#     191 else:
# --> 192     chunker = ne_chunker()
#     193 return chunker.parse(tagged_tokens)
#
# File d:\Devansh\Amity\Sem 7\NLP\Lab\.venv\Lib\site-packages\nltk\chunk\__init__.py:174, in ne_chunker(fmt)
#     170 def ne_chunker(fmt="multiclass"):
#     171     """
#     172     Load NLTK's currently recommended named entity chunker.
#     173     """
# --> 174     return Maxent_NE_Chunker(fmt)
#
# File d:\Devansh\Amity\Sem 7\NLP\Lab\.venv\Lib\site-packages\nltk\chunk\named_entity.py:329, in Maxent_NE_Chunker.__init__(self, fmt)
#     326 from nltk.data import find
#     328 self._fmt = fmt
# --> 329 self._tab_dir = find(f"chunkers/maxent_ne_chunker_tab/english_ace_{fmt}/")
#     330 self.load_params()
#
# File d:\Devansh\Amity\Sem 7\NLP\Lab\.venv\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource maxent_ne_chunker_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('maxent_ne_chunker_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load chunkers/maxent_ne_chunker_tab/english_ace_multiclass/
#
#   Searched in:
#     - 'C:\\Users\\Devansh Kumar/nltk_data'
#     - 'd:\\Devansh\\Amity\\Sem 7\\NLP\\Lab\\.venv\\nltk_data'
#     - 'd:\\Devansh\\Amity\\Sem 7\\NLP\\Lab\\.venv\\share\\nltk_data'
#     - 'd:\\Devansh\\Amity\\Sem 7\\NLP\\Lab\\.venv\\lib\\nltk_data'
#     - 'C:\\Users\\Devansh Kumar\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
